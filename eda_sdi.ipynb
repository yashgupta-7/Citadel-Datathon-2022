# %%
import pandas as pd
df = pd.read_csv("data/SDI/All_Reports_20140331/All_Reports_20140331_Net Loans and Leases.csv")

# %%
df.groupby(['stalp']).sum()['lnlsnet'].reset_index().plot(x = 'stalp', y = 'lnlsnet', figsize=(30, 5))
# Out:
# <AxesSubplot:xlabel='stalp'>
